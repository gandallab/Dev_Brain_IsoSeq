# %% [markdown]
# ```
# conda activate .snakemake/conda/59fab4b877169aaff69a189e3f1daa5b
# ```
#
#
# ```
# talon_create_GTF \
#     --db results/talon/talon.db \
#     --build GRCh37 \
#     --annot gencode.v33lift37 \
#     --whitelist talon_whitelist.txt \
#     --o cp_vz_preliminary
# ```
#
# ```
# talon_abundance \
#     --db results/talon/talon.db \
#     --build GRCh37 \
#     --annot gencode.v33lift37 \
#     --whitelist talon_whitelist.txt \
#     --o cp_vz_preliminary
# ```

# %%
library("tidyverse")
library("ggplot2")
library("rtracklayer")
# Out:
# ── Attaching packages ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
#
# Loading required package: GenomeInfoDb

# %%
options(repr.plot.width = 6, repr.plot.height = 4, repr.plot.res = 300)

# %%
gtf = rtracklayer::import("cp_vz_preliminary_talon.gtf") %>% as_tibble()
gtf
# Out:
#         seqnames start     end       width strand source type       score phase
# 1       chr1     14404     21119      6716 -      HAVANA gene       NA    NA
# 2       chr1     14404     29570     15167 -      TALON  transcript NA    NA
# 3       chr1     29321     29570       250 -      TALON  exon       NA    NA
# 4       chr1     24738     24891       154 -      HAVANA exon       NA    NA
# 5       chr1     18913     19139       227 -      TALON  exon       NA    NA
# 6       chr1     18268     18369       102 -      TALON  exon       NA    NA
# 7       chr1     17915     18061       147 -      HAVANA exon       NA    NA
# 8       chr1     17606     17742       137 -      HAVANA exon       NA    NA
# 9       chr1     17233     17368       136 -      HAVANA exon       NA    NA
# 10      chr1     16858     17055       198 -      HAVANA exon       NA    NA
# 11      chr1     16607     16765       159 -      HAVANA exon       NA    NA
# 12      chr1     15796     15947       152 -      HAVANA exon       NA    NA
# 13      chr1     14970     15038        69 -      TALON  exon       NA    NA
# 14      chr1     14404     14829       426 -      TALON  exon       NA    NA
# 15      chr1     14404     21859      7456 -      TALON  transcript NA    NA
# 16      chr1     17915     21859      3945 -      TALON  exon       NA    NA
# 17      chr1     17233     17742       510 -      TALON  exon       NA    NA
# 18      chr1     16858     17055       198 -      HAVANA exon       NA    NA
# 19      chr1     14404     16765      2362 -      TALON  exon       NA    NA
# 20      chr1     14404     29570     15167 -      TALON  transcript NA    NA
# 21      chr1     29321     29570       250 -      TALON  exon       NA    NA
# 22      chr1     24738     24891       154 -      HAVANA exon       NA    NA
# 23      chr1     18913     20286      1374 -      TALON  exon       NA    NA
# 24      chr1     18268     18366        99 -      HAVANA exon       NA    NA
# 25      chr1     17915     18061       147 -      HAVANA exon       NA    NA
# 26      chr1     17606     17742       137 -      HAVANA exon       NA    NA
# 27      chr1     17233     17368       136 -      HAVANA exon       NA    NA
# 28      chr1     16858     17055       198 -      HAVANA exon       NA    NA
# 29      chr1     16607     16765       159 -      HAVANA exon       NA    NA
# 30      chr1     15796     15947       152 -      HAVANA exon       NA    NA
# ⋮       ⋮        ⋮         ⋮         ⋮     ⋮      ⋮      ⋮          ⋮     ⋮
# 3574213 chr4     136423911 136443348 19438 -      TALON  gene       NA    NA
# 3574214 chr4     136423911 136443348 19438 -      TALON  transcript NA    NA
# 3574215 chr4     136443200 136443348   149 -      TALON  exon       NA    NA
# 3574216 chr4     136428896 136429083   188 -      TALON  exon       NA    NA
# 3574217 chr4     136423911 136427205  3295 -      TALON  exon       NA    NA
# 3574218 chr9      83232908  83257410 24503 +      TALON  gene       NA    NA
# 3574219 chr9      83232908  83257410 24503 +      TALON  transcript NA    NA
# 3574220 chr9      83232908  83232997    90 +      TALON  exon       NA    NA
# 3574221 chr9      83251232  83251283    52 +      TALON  exon       NA    NA
# 3574222 chr9      83253589  83257410  3822 +      TALON  exon       NA    NA
# 3574223 chr6      73901304  73904521  3218 -      TALON  gene       NA    NA
# 3574224 chr6      73901304  73904521  3218 -      TALON  transcript NA    NA
# 3574225 chr6      73904179  73904521   343 -      TALON  exon       NA    NA
# 3574226 chr6      73901304  73902418  1115 -      TALON  exon       NA    NA
# 3574227 chr3     127409688 127413906  4219 +      TALON  gene       NA    NA
# 3574228 chr3     127409688 127413906  4219 +      TALON  transcript NA    NA
# 3574229 chr3     127409688 127411166  1479 +      TALON  exon       NA    NA
# 3574230 chr3     127413818 127413906    89 +      TALON  exon       NA    NA
# 3574231 chr17     75797147  75809812 12666 +      TALON  gene       NA    NA
# 3574232 chr17     75797147  75809812 12666 +      TALON  transcript NA    NA
# 3574233 chr17     75797147  75797233    87 +      TALON  exon       NA    NA
# 3574234 chr17     75808894  75809812   919 +      TALON  exon       NA    NA
# 3574235 chr1      98509852  98512873  3022 +      TALON  gene       NA    NA
# 3574236 chr1      98509852  98512873  3022 +      TALON  transcript NA    NA
# 3574237 chr1      98509852  98509869    18 +      TALON  exon       NA    NA
# 3574238 chr1      98510237  98512873  2637 +      TALON  exon       NA    NA
# 3574239 chr1     147752772 147761669  8898 +      TALON  gene       NA    NA
# 3574240 chr1     147752772 147761669  8898 +      TALON  transcript NA    NA
# 3574241 chr1     147752772 147754674  1903 +      TALON  exon       NA    NA
# 3574242 chr1     147759796 147761669  1874 +      TALON  exon       NA    NA
#         gene_id             ⋯ gencode_transcript_status havana_transcript
# 1       ENSG00000227232.5_3 ⋯ NA                        NA
# 2       ENSG00000227232.5_3 ⋯ NA                        NA
# 3       ENSG00000227232.5_3 ⋯ NA                        NA
# 4       ENSG00000227232.5_3 ⋯ NA                        NA
# 5       ENSG00000227232.5_3 ⋯ NA                        NA
# 6       ENSG00000227232.5_3 ⋯ NA                        NA
# 7       ENSG00000227232.5_3 ⋯ NA                        NA
# 8       ENSG00000227232.5_3 ⋯ NA                        NA
# 9       ENSG00000227232.5_3 ⋯ NA                        NA
# 10      ENSG00000227232.5_3 ⋯ NA                        NA
# 11      ENSG00000227232.5_3 ⋯ NA                        NA
# 12      ENSG00000227232.5_3 ⋯ NA                        NA
# 13      ENSG00000227232.5_3 ⋯ NA                        NA
# 14      ENSG00000227232.5_3 ⋯ NA                        NA
# 15      ENSG00000227232.5_3 ⋯ NA                        NA
# 16      ENSG00000227232.5_3 ⋯ NA                        NA
# 17      ENSG00000227232.5_3 ⋯ NA                        NA
# 18      ENSG00000227232.5_3 ⋯ NA                        NA
# 19      ENSG00000227232.5_3 ⋯ NA                        NA
# 20      ENSG00000227232.5_3 ⋯ NA                        NA
# 21      ENSG00000227232.5_3 ⋯ NA                        NA
# 22      ENSG00000227232.5_3 ⋯ NA                        NA
# 23      ENSG00000227232.5_3 ⋯ NA                        NA
# 24      ENSG00000227232.5_3 ⋯ NA                        NA
# 25      ENSG00000227232.5_3 ⋯ NA                        NA
# 26      ENSG00000227232.5_3 ⋯ NA                        NA
# 27      ENSG00000227232.5_3 ⋯ NA                        NA
# 28      ENSG00000227232.5_3 ⋯ NA                        NA
# 29      ENSG00000227232.5_3 ⋯ NA                        NA
# 30      ENSG00000227232.5_3 ⋯ NA                        NA
# ⋮       ⋮                   ⋱ ⋮                         ⋮
# 3574213 TALONG000178111     ⋯ NA                        NA
# 3574214 TALONG000178111     ⋯ NA                        NA
# 3574215 TALONG000178111     ⋯ NA                        NA
# 3574216 TALONG000178111     ⋯ NA                        NA
# 3574217 TALONG000178111     ⋯ NA                        NA
# 3574218 TALONG000178255     ⋯ NA                        NA
# 3574219 TALONG000178255     ⋯ NA                        NA
# 3574220 TALONG000178255     ⋯ NA                        NA
# 3574221 TALONG000178255     ⋯ NA                        NA
# 3574222 TALONG000178255     ⋯ NA                        NA
# 3574223 TALONG000179609     ⋯ NA                        NA
# 3574224 TALONG000179609     ⋯ NA                        NA
# 3574225 TALONG000179609     ⋯ NA                        NA
# 3574226 TALONG000179609     ⋯ NA                        NA
# 3574227 TALONG000180582     ⋯ NA                        NA
# 3574228 TALONG000180582     ⋯ NA                        NA
# 3574229 TALONG000180582     ⋯ NA                        NA
# 3574230 TALONG000180582     ⋯ NA                        NA
# 3574231 TALONG000182469     ⋯ NA                        NA
# 3574232 TALONG000182469     ⋯ NA                        NA
# 3574233 TALONG000182469     ⋯ NA                        NA
# 3574234 TALONG000182469     ⋯ NA                        NA
# 3574235 TALONG000183977     ⋯ NA                        NA
# 3574236 TALONG000183977     ⋯ NA                        NA
# 3574237 TALONG000183977     ⋯ NA                        NA
# 3574238 TALONG000183977     ⋯ NA                        NA
# 3574239 TALONG000184265     ⋯ NA                        NA
# 3574240 TALONG000184265     ⋯ NA                        NA
# 3574241 TALONG000184265     ⋯ NA                        NA
# 3574242 TALONG000184265     ⋯ NA                        NA
#         transcript_support_level ccdsid protein_id intergenic_novel
# 1       NA                       NA     NA         NA
# 2       NA                       NA     NA         NA
# 3       NA                       NA     NA         NA
# 4       NA                       NA     NA         NA
# 5       NA                       NA     NA         NA
# 6       NA                       NA     NA         NA
# 7       NA                       NA     NA         NA
# 8       NA                       NA     NA         NA
# 9       NA                       NA     NA         NA
# 10      NA                       NA     NA         NA
# 11      NA                       NA     NA         NA
# 12      NA                       NA     NA         NA
# 13      NA                       NA     NA         NA
# 14      NA                       NA     NA         NA
# 15      NA                       NA     NA         NA
# 16      NA                       NA     NA         NA
# 17      NA                       NA     NA         NA
# 18      NA                       NA     NA         NA
# 19      NA                       NA     NA         NA
# 20      NA                       NA     NA         NA
# 21      NA                       NA     NA         NA
# 22      NA                       NA     NA         NA
# 23      NA                       NA     NA         NA
# 24      NA                       NA     NA         NA
# 25      NA                       NA     NA         NA
# 26      NA                       NA     NA         NA
# 27      NA                       NA     NA         NA
# 28      NA                       NA     NA         NA
# 29      NA                       NA     NA         NA
# 30      NA                       NA     NA         NA
# ⋮       ⋮                        ⋮      ⋮          ⋮
# 3574213 NA                       NA     NA         TRUE
# 3574214 NA                       NA     NA         NA
# 3574215 NA                       NA     NA         NA
# 3574216 NA                       NA     NA         NA
# 3574217 NA                       NA     NA         NA
# 3574218 NA                       NA     NA         TRUE
# 3574219 NA                       NA     NA         NA
# 3574220 NA                       NA     NA         NA
# 3574221 NA                       NA     NA         NA
# 3574222 NA                       NA     NA         NA
# 3574223 NA                       NA     NA         NA
# 3574224 NA                       NA     NA         NA
# 3574225 NA                       NA     NA         NA
# 3574226 NA                       NA     NA         NA
# 3574227 NA                       NA     NA         NA
# 3574228 NA                       NA     NA         NA
# 3574229 NA                       NA     NA         NA
# 3574230 NA                       NA     NA         NA
# 3574231 NA                       NA     NA         NA
# 3574232 NA                       NA     NA         NA
# 3574233 NA                       NA     NA         NA
# 3574234 NA                       NA     NA         NA
# 3574235 NA                       NA     NA         NA
# 3574236 NA                       NA     NA         NA
# 3574237 NA                       NA     NA         NA
# 3574238 NA                       NA     NA         NA
# 3574239 NA                       NA     NA         NA
# 3574240 NA                       NA     NA         NA
# 3574241 NA                       NA     NA         NA
# 3574242 NA                       NA     NA         NA
#         intergenic_transcript antisense_gene gene_antisense_to_IDs
# 1       NA                    NA             NA
# 2       NA                    NA             NA
# 3       NA                    NA             NA
# 4       NA                    NA             NA
# 5       NA                    NA             NA
# 6       NA                    NA             NA
# 7       NA                    NA             NA
# 8       NA                    NA             NA
# 9       NA                    NA             NA
# 10      NA                    NA             NA
# 11      NA                    NA             NA
# 12      NA                    NA             NA
# 13      NA                    NA             NA
# 14      NA                    NA             NA
# 15      NA                    NA             NA
# 16      NA                    NA             NA
# 17      NA                    NA             NA
# 18      NA                    NA             NA
# 19      NA                    NA             NA
# 20      NA                    NA             NA
# 21      NA                    NA             NA
# 22      NA                    NA             NA
# 23      NA                    NA             NA
# 24      NA                    NA             NA
# 25      NA                    NA             NA
# 26      NA                    NA             NA
# 27      NA                    NA             NA
# 28      NA                    NA             NA
# 29      NA                    NA             NA
# 30      NA                    NA             NA
# ⋮       ⋮                     ⋮              ⋮
# 3574213 NA                    NA             NA
# 3574214 NA                    NA             NA
# 3574215 NA                    NA             NA
# 3574216 NA                    NA             NA
# 3574217 NA                    NA             NA
# 3574218 NA                    NA             NA
# 3574219 TRUE                  NA             NA
# 3574220 NA                    NA             NA
# 3574221 NA                    NA             NA
# 3574222 NA                    NA             NA
# 3574223 NA                    TRUE           20926
# 3574224 NA                    NA             NA
# 3574225 NA                    NA             NA
# 3574226 NA                    NA             NA
# 3574227 NA                    TRUE           12090
# 3574228 NA                    NA             NA
# 3574229 NA                    NA             NA
# 3574230 NA                    NA             NA
# 3574231 NA                    TRUE           182468
# 3574232 NA                    NA             NA
# 3574233 NA                    NA             NA
# 3574234 NA                    NA             NA
# 3574235 NA                    TRUE           2492
# 3574236 NA                    NA             NA
# 3574237 NA                    NA             NA
# 3574238 NA                    NA             NA
# 3574239 NA                    TRUE           3138
# 3574240 NA                    NA             NA
# 3574241 NA                    NA             NA
# 3574242 NA                    NA             NA
#         antisense_transcript
# 1       NA
# 2       NA
# 3       NA
# 4       NA
# 5       NA
# 6       NA
# 7       NA
# 8       NA
# 9       NA
# 10      NA
# 11      NA
# 12      NA
# 13      NA
# 14      NA
# 15      NA
# 16      NA
# 17      NA
# 18      NA
# 19      NA
# 20      NA
# 21      NA
# 22      NA
# 23      NA
# 24      NA
# 25      NA
# 26      NA
# 27      NA
# 28      NA
# 29      NA
# 30      NA
# ⋮       ⋮
# 3574213 NA
# 3574214 NA
# 3574215 NA
# 3574216 NA
# 3574217 NA
# 3574218 NA
# 3574219 NA
# 3574220 NA
# 3574221 NA
# 3574222 NA
# 3574223 NA
# 3574224 TRUE
# 3574225 NA
# 3574226 NA
# 3574227 NA
# 3574228 TRUE
# 3574229 NA
# 3574230 NA
# 3574231 NA
# 3574232 TRUE
# 3574233 NA
# 3574234 NA
# 3574235 NA
# 3574236 TRUE
# 3574237 NA
# 3574238 NA
# 3574239 NA
# 3574240 TRUE
# 3574241 NA
# 3574242 NA

# %%
transcripts = gtf %>% filter(type == "transcript") %>% select(where(~!all(is.na(.x))))
transcripts
# Out:
#        seqnames   start     end       width strand source type
# 1      chr1       14404     29570     15167 -      TALON  transcript
# 2      chr1       14404     21859      7456 -      TALON  transcript
# 3      chr1       14404     29570     15167 -      TALON  transcript
# 4      chr1       14404     29570     15167 -      TALON  transcript
# 5      chr1       14404     21119      6716 -      TALON  transcript
# 6      chr1       14404     24891     10488 -      TALON  transcript
# 7      chr1       14404     29570     15167 -      TALON  transcript
# 8      chr1       14404     29570     15167 -      TALON  transcript
# 9      chr1       14404     29570     15167 -      TALON  transcript
# 10     chr1       14404     29570     15167 -      TALON  transcript
# 11     chr1       14404     29570     15167 -      TALON  transcript
# 12     chr1       14404     24891     10488 -      TALON  transcript
# 13     chr1       14404     29570     15167 -      TALON  transcript
# 14     chr1       14404     29570     15167 -      TALON  transcript
# 15     chr1       14404     18913      4510 -      TALON  transcript
# 16     chr1       14404     20286      5883 -      TALON  transcript
# 17     chr1       14404     20960      6557 -      TALON  transcript
# 18     chr1       14404     20286      5883 -      TALON  transcript
# 19     chr1       14404     21119      6716 -      TALON  transcript
# 20     chr1       14404     21859      7456 -      TALON  transcript
# 21     chr1       14404     20960      6557 -      TALON  transcript
# 22     chr1       14404     29570     15167 -      TALON  transcript
# 23     chr1       14404     20286      5883 -      TALON  transcript
# 24     chr1       14404     29570     15167 -      TALON  transcript
# 25     chr1       14404     29570     15167 -      TALON  transcript
# 26     chr1       14404     29570     15167 -      TALON  transcript
# 27     chr1       14404     19139      4736 -      TALON  transcript
# 28     chr1       14404     29570     15167 -      TALON  transcript
# 29     chr1       14404     29570     15167 -      TALON  transcript
# 30     chr1       14404     29570     15167 -      TALON  transcript
# ⋮      ⋮          ⋮         ⋮         ⋮     ⋮      ⋮      ⋮
# 303944 chr1       193155458 193222052 66595 -      TALON  transcript
# 303945 chr1       197735613 197762755 27143 +      TALON  transcript
# 303946 GL000219.1     20258     42804 22547 -      TALON  transcript
# 303947 chr18       32660739  32662284  1546 -      TALON  transcript
# 303948 chr13       76393634  76427524 33891 -      TALON  transcript
# 303949 chr20       29518749  29524330  5582 +      TALON  transcript
# 303950 chr5        11880557  11882345  1789 +      TALON  transcript
# 303951 chr10      135201662 135204080  2419 -      TALON  transcript
# 303952 chr4       142253857 142352438 98582 +      TALON  transcript
# 303953 chr4       152090488 152095300  4813 +      TALON  transcript
# 303954 chr4       171350197 171369137 18941 +      TALON  transcript
# 303955 chr9        96072724  96079001  6278 -      TALON  transcript
# 303956 chrX        56254558  56258789  4232 -      TALON  transcript
# 303957 chr11      115991356 116028840 37485 -      TALON  transcript
# 303958 chr8       144699722 144715620 15899 +      TALON  transcript
# 303959 chr17       80965111  80974002  8892 +      TALON  transcript
# 303960 chr17       80965919  80974002  8084 +      TALON  transcript
# 303961 chr2       242671572 242674017  2446 -      TALON  transcript
# 303962 GL000238.1     11327     36218 24892 +      TALON  transcript
# 303963 GL000238.1     11327     36218 24892 +      TALON  transcript
# 303964 GL000238.1     11327     36218 24892 +      TALON  transcript
# 303965 chr10       23460165  23463471  3307 -      TALON  transcript
# 303966 chr8          618598    622681  4084 +      TALON  transcript
# 303967 chr4       136423911 136443348 19438 -      TALON  transcript
# 303968 chr9        83232908  83257410 24503 +      TALON  transcript
# 303969 chr6        73901304  73904521  3218 -      TALON  transcript
# 303970 chr3       127409688 127413906  4219 +      TALON  transcript
# 303971 chr17       75797147  75809812 12666 +      TALON  transcript
# 303972 chr1        98509852  98512873  3022 +      TALON  transcript
# 303973 chr1       147752772 147761669  8898 +      TALON  transcript
#        gene_id             gene_name       gene_status ⋯
# 1      ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 2      ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 3      ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 4      ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 5      ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 6      ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 7      ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 8      ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 9      ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 10     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 11     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 12     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 13     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 14     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 15     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 16     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 17     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 18     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 19     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 20     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 21     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 22     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 23     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 24     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 25     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 26     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 27     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 28     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 29     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# 30     ENSG00000227232.5_3 WASH7P          KNOWN       ⋯
# ⋮      ⋮                   ⋮               ⋮           ⋱
# 303944 TALONG000149143     TALONG000149143 NOVEL       ⋯
# 303945 TALONG000149180     TALONG000149180 NOVEL       ⋯
# 303946 TALONG000149949     TALONG000149949 NOVEL       ⋯
# 303947 TALONG000151539     TALONG000151539 NOVEL       ⋯
# 303948 TALONG000151835     TALONG000151835 NOVEL       ⋯
# 303949 TALONG000152377     TALONG000152377 NOVEL       ⋯
# 303950 TALONG000154053     TALONG000154053 NOVEL       ⋯
# 303951 TALONG000159527     TALONG000159527 NOVEL       ⋯
# 303952 TALONG000160441     TALONG000160441 NOVEL       ⋯
# 303953 TALONG000160921     TALONG000160921 NOVEL       ⋯
# 303954 TALONG000161978     TALONG000161978 NOVEL       ⋯
# 303955 TALONG000162637     TALONG000162637 NOVEL       ⋯
# 303956 TALONG000163175     TALONG000163175 NOVEL       ⋯
# 303957 TALONG000165266     TALONG000165266 NOVEL       ⋯
# 303958 TALONG000166288     TALONG000166288 NOVEL       ⋯
# 303959 TALONG000169086     TALONG000169086 NOVEL       ⋯
# 303960 TALONG000169086     TALONG000169086 NOVEL       ⋯
# 303961 TALONG000170219     TALONG000170219 NOVEL       ⋯
# 303962 TALONG000171040     TALONG000171040 NOVEL       ⋯
# 303963 TALONG000171040     TALONG000171040 NOVEL       ⋯
# 303964 TALONG000171040     TALONG000171040 NOVEL       ⋯
# 303965 TALONG000171269     TALONG000171269 NOVEL       ⋯
# 303966 TALONG000175836     TALONG000175836 NOVEL       ⋯
# 303967 TALONG000178111     TALONG000178111 NOVEL       ⋯
# 303968 TALONG000178255     TALONG000178255 NOVEL       ⋯
# 303969 TALONG000179609     TALONG000179609 NOVEL       ⋯
# 303970 TALONG000180582     TALONG000180582 NOVEL       ⋯
# 303971 TALONG000182469     TALONG000182469 NOVEL       ⋯
# 303972 TALONG000183977     TALONG000183977 NOVEL       ⋯
# 303973 TALONG000184265     TALONG000184265 NOVEL       ⋯
#        remap_substituted_missing_target genomic_transcript transcript_type
# 1      NA                               NA                 NA
# 2      NA                               NA                 NA
# 3      NA                               NA                 NA
# 4      NA                               NA                 NA
# 5      NA                               NA                 NA
# 6      NA                               NA                 NA
# 7      NA                               NA                 NA
# 8      NA                               NA                 NA
# 9      NA                               NA                 NA
# 10     NA                               NA                 NA
# 11     NA                               NA                 NA
# 12     NA                               NA                 NA
# 13     NA                               NA                 NA
# 14     NA                               NA                 NA
# 15     NA                               NA                 NA
# 16     NA                               NA                 NA
# 17     NA                               NA                 NA
# 18     NA                               NA                 NA
# 19     NA                               NA                 NA
# 20     NA                               NA                 NA
# 21     NA                               NA                 NA
# 22     NA                               NA                 NA
# 23     NA                               NA                 NA
# 24     NA                               NA                 NA
# 25     NA                               NA                 NA
# 26     NA                               NA                 NA
# 27     NA                               NA                 NA
# 28     NA                               NA                 NA
# 29     NA                               NA                 NA
# 30     NA                               NA                 NA
# ⋮      ⋮                                ⋮                  ⋮
# 303944 NA                               NA                 NA
# 303945 NA                               NA                 NA
# 303946 NA                               TRUE               NA
# 303947 NA                               NA                 NA
# 303948 NA                               NA                 NA
# 303949 NA                               NA                 NA
# 303950 NA                               TRUE               NA
# 303951 NA                               TRUE               NA
# 303952 NA                               NA                 NA
# 303953 NA                               NA                 NA
# 303954 NA                               NA                 NA
# 303955 NA                               TRUE               NA
# 303956 NA                               NA                 NA
# 303957 NA                               NA                 NA
# 303958 NA                               NA                 NA
# 303959 NA                               TRUE               NA
# 303960 NA                               NA                 NA
# 303961 NA                               NA                 NA
# 303962 NA                               NA                 NA
# 303963 NA                               NA                 NA
# 303964 NA                               NA                 NA
# 303965 NA                               NA                 NA
# 303966 NA                               NA                 NA
# 303967 NA                               NA                 NA
# 303968 NA                               NA                 NA
# 303969 NA                               NA                 NA
# 303970 NA                               NA                 NA
# 303971 NA                               NA                 NA
# 303972 NA                               NA                 NA
# 303973 NA                               NA                 NA
#        gencode_transcript_status havana_transcript transcript_support_level
# 1      NA                        NA                NA
# 2      NA                        NA                NA
# 3      NA                        NA                NA
# 4      NA                        NA                NA
# 5      NA                        NA                NA
# 6      NA                        NA                NA
# 7      NA                        NA                NA
# 8      NA                        NA                NA
# 9      NA                        NA                NA
# 10     NA                        NA                NA
# 11     NA                        NA                NA
# 12     NA                        NA                NA
# 13     NA                        NA                NA
# 14     NA                        NA                NA
# 15     NA                        NA                NA
# 16     NA                        NA                NA
# 17     NA                        NA                NA
# 18     NA                        NA                NA
# 19     NA                        NA                NA
# 20     NA                        NA                NA
# 21     NA                        NA                NA
# 22     NA                        NA                NA
# 23     NA                        NA                NA
# 24     NA                        NA                NA
# 25     NA                        NA                NA
# 26     NA                        NA                NA
# 27     NA                        NA                NA
# 28     NA                        NA                NA
# 29     NA                        NA                NA
# 30     NA                        NA                NA
# ⋮      ⋮                         ⋮                 ⋮
# 303944 NA                        NA                NA
# 303945 NA                        NA                NA
# 303946 NA                        NA                NA
# 303947 NA                        NA                NA
# 303948 NA                        NA                NA
# 303949 NA                        NA                NA
# 303950 NA                        NA                NA
# 303951 NA                        NA                NA
# 303952 NA                        NA                NA
# 303953 NA                        NA                NA
# 303954 NA                        NA                NA
# 303955 NA                        NA                NA
# 303956 NA                        NA                NA
# 303957 NA                        NA                NA
# 303958 NA                        NA                NA
# 303959 NA                        NA                NA
# 303960 NA                        NA                NA
# 303961 NA                        NA                NA
# 303962 NA                        NA                NA
# 303963 NA                        NA                NA
# 303964 NA                        NA                NA
# 303965 NA                        NA                NA
# 303966 NA                        NA                NA
# 303967 NA                        NA                NA
# 303968 NA                        NA                NA
# 303969 NA                        NA                NA
# 303970 NA                        NA                NA
# 303971 NA                        NA                NA
# 303972 NA                        NA                NA
# 303973 NA                        NA                NA
#        ccdsid protein_id intergenic_transcript antisense_transcript
# 1      NA     NA         NA                    NA
# 2      NA     NA         NA                    NA
# 3      NA     NA         NA                    NA
# 4      NA     NA         NA                    NA
# 5      NA     NA         NA                    NA
# 6      NA     NA         NA                    NA
# 7      NA     NA         NA                    NA
# 8      NA     NA         NA                    NA
# 9      NA     NA         NA                    NA
# 10     NA     NA         NA                    NA
# 11     NA     NA         NA                    NA
# 12     NA     NA         NA                    NA
# 13     NA     NA         NA                    NA
# 14     NA     NA         NA                    NA
# 15     NA     NA         NA                    NA
# 16     NA     NA         NA                    NA
# 17     NA     NA         NA                    NA
# 18     NA     NA         NA                    NA
# 19     NA     NA         NA                    NA
# 20     NA     NA         NA                    NA
# 21     NA     NA         NA                    NA
# 22     NA     NA         NA                    NA
# 23     NA     NA         NA                    NA
# 24     NA     NA         NA                    NA
# 25     NA     NA         NA                    NA
# 26     NA     NA         NA                    NA
# 27     NA     NA         NA                    NA
# 28     NA     NA         NA                    NA
# 29     NA     NA         NA                    NA
# 30     NA     NA         NA                    NA
# ⋮      ⋮      ⋮          ⋮                     ⋮
# 303944 NA     NA         NA                    NA
# 303945 NA     NA         NA                    TRUE
# 303946 NA     NA         NA                    NA
# 303947 NA     NA         NA                    TRUE
# 303948 NA     NA         NA                    TRUE
# 303949 NA     NA         NA                    TRUE
# 303950 NA     NA         NA                    NA
# 303951 NA     NA         NA                    NA
# 303952 NA     NA         NA                    NA
# 303953 NA     NA         NA                    TRUE
# 303954 NA     NA         TRUE                  NA
# 303955 NA     NA         NA                    NA
# 303956 NA     NA         NA                    TRUE
# 303957 NA     NA         NA                    NA
# 303958 NA     NA         NA                    TRUE
# 303959 NA     NA         NA                    NA
# 303960 NA     NA         NA                    NA
# 303961 NA     NA         NA                    TRUE
# 303962 NA     NA         TRUE                  NA
# 303963 NA     NA         NA                    NA
# 303964 NA     NA         NA                    NA
# 303965 NA     NA         TRUE                  NA
# 303966 NA     NA         NA                    NA
# 303967 NA     NA         NA                    NA
# 303968 NA     NA         TRUE                  NA
# 303969 NA     NA         NA                    TRUE
# 303970 NA     NA         NA                    TRUE
# 303971 NA     NA         NA                    TRUE
# 303972 NA     NA         NA                    TRUE
# 303973 NA     NA         NA                    TRUE

# %%
colnames(transcripts)
# Out:
#  [1] "seqnames"                         "start"
#  [3] "end"                              "width"
#  [5] "strand"                           "source"
#  [7] "type"                             "gene_id"
#  [9] "gene_name"                        "gene_status"
# [11] "gene_type"                        "talon_gene"
# [13] "hgnc_id"                          "level"
# [15] "remap_num_mappings"               "remap_status"
# [17] "remap_target_status"              "transcript_id"
# [19] "transcript_status"                "transcript_name"
# [21] "talon_transcript"                 "NNC_transcript"
# [23] "ont"                              "source.1"
# [25] "tag"                              "NIC_transcript"
# [27] "ISM.prefix_to_IDs"                "ISM.prefix_transcript"
# [29] "ISM_to_IDs"                       "ISM_transcript"
# [31] "ISM.suffix_to_IDs"                "ISM.suffix_transcript"
# [33] "remap_substituted_missing_target" "genomic_transcript"
# [35] "transcript_type"                  "gencode_transcript_status"
# [37] "havana_transcript"                "transcript_support_level"
# [39] "ccdsid"                           "protein_id"
# [41] "intergenic_transcript"            "antisense_transcript"

# %%
n_distinct(transcripts$transcript_id)
# Out:
# [1] 303973

# %%
transcripts = transcripts %>% mutate(novelty = case_when(
    transcript_status == "KNOWN" ~ "Known",
    ISM_transcript == "TRUE" ~ "ISM",
    genomic_transcript == "TRUE" ~ "Genomic",
    NIC_transcript == "TRUE" ~ "NIC",
    NNC_transcript == "TRUE" ~ "NNC",
    antisense_transcript == "TRUE" ~ "Antisense",
    intergenic_transcript == "TRUE" ~ "Intergenic"
) %>% fct_infreq() %>% fct_relevel("Known"))

# %%
unique(transcripts$novelty)
# Out:
# [1] NNC        NIC        ISM        Genomic    Known      Intergenic Antisense
# Levels: Known ISM NIC NNC Genomic Antisense Intergenic

# %%
transcripts = transcripts %>%
    mutate(novelty = novelty %>% fct_other(drop = c("Antisense", "Genomic", "Intergenic")))

# %%
colors = c(
  "Known" = "#009E73",
  "ISM"   = "#0072B2",
  "NIC"   = "#D55E00",
  "NNC"   = "#E69F00",
  "Other" = "#000000"
)

# %%
iso_types = transcripts %>%
    count(novelty) %>%
    mutate(freq = n/sum(n)) %>%
    mutate(prop = n / sum(n) * 100) %>%
    mutate(prop_formatted = sprintf("%.1f%%", prop))

ggplot(iso_types, aes(x = novelty, y = n, fill=novelty)) +
    geom_col() +
    geom_text(
        aes(label = prop_formatted),
        vjust = c(1.5, 1.5, 1.5, 1.5, -0.2),
        colour = c("white", "white", "white", "white", "black")
    ) +
    scale_y_continuous(labels = scales::comma) +
    scale_fill_manual(values = colors) +
    guides(fill = "none") +
    xlab("Category") +
    ylab("Number of transcripts")
# Out:
# plot without title

# %%
exons = gtf %>%
    filter(type == "exon") %>%
    left_join(select(transcripts, transcript_id, novelty), by = "transcript_id")

# %%
tx_lengths = exons %>%
  group_by(transcript_id, novelty) %>%
  summarize(length = sum(width)) %>%
  mutate(novelty_simple = novelty %>% fct_other(keep = "Known", other_level = "Novel")) %>%
  drop_na()
# Out:
# `summarise()` has grouped output by 'transcript_id'. You can override using the `.groups` argument.

# %%
ggplot(tx_lengths, aes(x = length, fill = novelty)) +
  geom_histogram(bins = 75) +
  scale_x_continuous(limits = c(0, 11000)) +
  coord_cartesian(xlim = c(0, 10000)) +
  labs(
    x = "Transcript length (bp)",
    y = "Count",
    fill = "Category"
  ) +
  scale_fill_manual(
    values = colors,
    breaks = c("Known", "ISM", "NIC", "NNC", "Other")
  ) + 
  theme_gray(base_size = 14) + 
  theme(
    legend.position = c(.954545454545455, .9321562368),
    legend.justification = c(1, 1),
    axis.text = element_text(color="black")
  )
# Out:
# Warning message:
# “Removed 303 rows containing non-finite values (stat_bin).”
# Warning message:
# “Removed 10 rows containing missing values (geom_bar).”
# plot without title

# %%
levels = c(
  "Protein coding" = "protein_coding",
  "lncRNA" = "lncRNA",
  {
    x = str_subset(unique(gtf$gene_type), "pseudogene")
    names(x) = rep("Pseudogene", each = length(x))
    x
  },
  "Novel gene" = "Novel gene",
  "lincRNA" = "lincRNA"
)

gene_types = gtf %>%
  filter(type == "gene") %>%
  select(gene_id, gene_type) %>%
  mutate(
    gene_type = gene_type %>%
      replace_na("Novel gene") %>%
      fct_recode(!!!levels) %>%
      fct_other(keep = unique(names(levels))) %>%
      fct_relevel(unique(names(levels)))
  )

# %%
ggplot(gene_types, aes(y = fct_rev(gene_type))) +
  geom_bar(aes(x = (..count..)/sum(..count..), fill = gene_type)) +
  scale_x_continuous(labels = scales::label_percent()) +
  guides(fill = "none") +
  labs(
    x = "Percentage",
    y = "Gene type"
  ) +
  theme_gray(base_size = 14)
# Out:
# plot without title
